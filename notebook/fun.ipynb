# %%
def print_star():
    print("****")

# %%
print_star()
# Out:
# ****

# %%
def print_ch(n,ch):
    print(n*ch)

# %%
print_ch(10,"*")
# Out:
# **********

# %%
print_ch(5,"v")
# Out:
# vvvvv

# %%
def square_2(x):
    return x**2

# %%
square_2(5)
# Out:
# 25
